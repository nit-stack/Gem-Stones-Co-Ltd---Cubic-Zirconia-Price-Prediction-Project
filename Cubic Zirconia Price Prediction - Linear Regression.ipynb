# %%
# %matplotlib inline

# %%
import numpy as np  
from sklearn.linear_model import LinearRegression
import pandas as pd 
import matplotlib.pyplot as plt   
import matplotlib.style
plt.style.use('classic')
import seaborn as sns

# %%
df = pd.read_csv(r"C:\Users\Muthu B\Downloads\cubic_zirconia-1.csv")

# %%
df.head(50)
# Out:
#     Unnamed: 0  carat        cut color clarity  depth  table     x     y  \
# 0            1   0.30      Ideal     E     SI1   62.1   58.0  4.27  4.29
# 1            2   0.33    Premium     G      IF   60.8   58.0  4.42  4.46
# 2            3   0.90  Very Good     E    VVS2   62.2   60.0  6.04  6.12
# 3            4   0.42      Ideal     F     VS1   61.6   56.0  4.82  4.80
# 4            5   0.31      Ideal     F    VVS1   60.4   59.0  4.35  4.43
# 5            6   1.02      Ideal     D     VS2   61.5   56.0  6.46  6.49
# 6            7   1.01       Good     H     SI1   63.7   60.0  6.35  6.30
# 7            8   0.50    Premium     E     SI1   61.5   62.0  5.09  5.06
# 8            9   1.21       Good     H     SI1   63.8   64.0  6.72  6.63
# 9           10   0.35      Ideal     F     VS2   60.5   57.0  4.52  4.60
# 10          11   0.32      Ideal     E     VS2   61.6   56.0  4.40  4.43
# 11          12   1.10    Premium     D     SI1   60.7   55.0  6.74  6.71
# ...

# %%
df.shape
# Out:
# (26967, 11)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26967 entries, 0 to 26966
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  26967 non-null  int64
#  1   carat       26967 non-null  float64
#  2   cut         26967 non-null  object
#  3   color       26967 non-null  object
#  4   clarity     26967 non-null  object
#  5   depth       26270 non-null  float64
#  6   table       26967 non-null  float64
#  7   x           26967 non-null  float64
#  8   y           26967 non-null  float64
#  9   z           26967 non-null  float64
#  10  price       26967 non-null  int64
# dtypes: float64(6), int64(2), object(3)
# memory usage: 2.3+ MB

# %%
dups = df.duplicated()
print('Number of duplicate rows = %d' % (dups.sum()))
df[dups]
# Out:
# Number of duplicate rows = 0
# Empty DataFrame
# Columns: [Unnamed: 0, carat, cut, color, clarity, depth, table, x, y, z, price]
# Index: []

# %%
df.isnull().sum()
# Out:
# Unnamed: 0      0
# carat           0
# cut             0
# color           0
# clarity         0
# depth         697
# table           0
# x               0
# y               0
# z               0
# price           0
# dtype: int64

# %%
df = df.drop('Unnamed: 0', axis=1)

# %%
df.plot(kind='box', figsize = (30,30), fontsize=20, patch_artist=True)

# %%
for feature in df.columns: 
    if df[feature].dtype == 'object': 
        df[feature] = pd.Categorical(df[feature]).codes

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26967 entries, 0 to 26966
# Data columns (total 10 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   carat    26967 non-null  float64
#  1   cut      26967 non-null  int8
#  2   color    26967 non-null  int8
#  3   clarity  26967 non-null  int8
#  4   depth    26270 non-null  float64
#  5   table    26967 non-null  float64
#  6   x        26967 non-null  float64
#  7   y        26967 non-null  float64
#  8   z        26967 non-null  float64
#  9   price    26967 non-null  int64
# dtypes: float64(6), int64(1), int8(3)
# memory usage: 1.5 MB

# %%
df
# Out:
#        carat  cut  color  clarity  depth  table     x     y     z   price
# 0       0.30    2      1        2   62.1   58.0  4.27  4.29  2.66   499.0
# 1       0.33    3      3        1   60.8   58.0  4.42  4.46  2.70   984.0
# 2       0.90    4      1        7   62.2   60.0  6.04  6.12  3.78  6289.0
# 3       0.42    2      2        4   61.6   56.0  4.82  4.80  2.96  1082.0
# 4       0.31    2      2        6   60.4   59.0  4.35  4.43  2.65   779.0
# ...      ...  ...    ...      ...    ...    ...   ...   ...   ...     ...
# 26962   1.11    3      3        2   62.3   58.0  6.61  6.52  4.09  5408.0
# 26963   0.33    2      4        1   61.9   55.0  4.44  4.42  2.74  1114.0
# 26964   0.51    3      1        5   61.7   58.0  5.12  5.15  3.17  1656.0
# 26965   0.27    4      2        7   61.8   56.0  4.19  4.20  2.60   682.0
# 26966   1.25    3      6        2   62.0   58.0  6.90  6.88  4.27  5166.0
#
# [26967 rows x 10 columns]

# %%
sns.distplot(df);

# %%
sns.distplot(df, hist=False);

# %%
sns.violinplot(df)

# %%
sns.distplot(df, hist_kws=dict(cumulative=True), kde_kws=dict(cumulative=True))

# %%
sns.pairplot(df)

# %%
sns.heatmap(df.corr(), cmap='YlGnBu', annot=True)

# %%
df[df.isnull().any(axis=1)]
# Out:
#        carat  cut  color  clarity  depth  table     x     y     z  price
# 26      0.34    2      0        2    NaN   57.0  4.50  4.44  2.74    803
# 86      0.74    2      1        3    NaN   59.0  5.92  5.97  3.52   2501
# 117     1.00    3      2        2    NaN   59.0  6.40  6.36  4.00   5292
# 148     1.11    3      1        3    NaN   61.0  6.66  6.61  4.09   4177
# 163     1.00    4      2        5    NaN   55.0  6.39  6.44  3.99   6340
# ...      ...  ...    ...      ...    ...    ...   ...   ...   ...    ...
# 26848   1.22    4      4        4    NaN   59.0  6.91  6.85  4.29   7673
# 26854   1.29    3      5        5    NaN   58.0  7.12  7.03  4.27   6321
# 26879   0.51    4      1        2    NaN   58.0  5.10  5.13  3.12   1343
# 26923   0.51    2      0        5    NaN   57.0  5.12  5.09  3.18   1882
# 26960   1.10    4      0        3    NaN   63.0  6.76  6.69  3.94   4361
#
# [697 rows x 10 columns]

# %%
df.median()
# Out:
# carat         0.70
# cut           2.00
# color         3.00
# clarity       4.00
# depth        61.80
# table        57.00
# x             5.69
# y             5.71
# z             3.52
# price      2375.00
# dtype: float64

# %%
df = df.apply(lambda x: x.fillna(x.median()),axis=0)

# %%
df.isnull().sum()
# Out:
# carat      0
# cut        0
# color      0
# clarity    0
# depth      0
# table      0
# x          0
# y          0
# z          0
# price      0
# dtype: int64

# %%
df.plot(kind='box', figsize = (30,30), fontsize=20, patch_artist=True)

# %%
sns.boxplot(x=df['price']);

# %%
Q1 = df.quantile(0.25) # Getting First quantile for all numerical variables
Q3 = df.quantile(0.75) # Getting Second quantile for all numerical variables
IQR = Q3 - Q1          # Getting IQR values
lower_range= Q1-(1.5 * IQR) #Getting Lower Limit for all numerical variables
upper_range= Q3+(1.5 * IQR) #Getting Upper Limit for all numerical variables

# %%
lower_range
# Out:
# carat        -0.575
# cut           0.500
# color        -3.500
# clarity      -2.500
# depth        59.000
# table        51.500
# x             1.950
# y             1.965
# z             1.190
# price     -5677.500
# dtype: float64

# %%
upper_range
# Out:
# carat          2.025
# cut            4.500
# color          8.500
# clarity        9.500
# depth         64.600
# table         63.500
# x              9.310
# y              9.285
# z              5.750
# price      11982.500
# dtype: float64

# %%
df['price']=np.where(df['price']> 11982.500,11982.500,df['price'])
df['price']=np.where(df['price']< -5677.500,-5677.500,df['price'])

# %%
sns.boxplot(x=df['price']);

# %%
df['x']=df['x'].replace(0,df['x'].median())

# %%
df['y']=df['y'].replace(0,df['y'].median())

# %%
df['z']=df['z'].replace(0,df['z'].median())

# %%
X = df.drop('price', axis=1)

y = df[['price']]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30 , random_state=1)

# %%
regression_model = LinearRegression()
regression_model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
for idx, col_name in enumerate(X_train.columns):
    print("The coefficient for {} is {}".format(col_name, regression_model.coef_[0][idx]))
# Out:
# The coefficient for carat is 6463.821170650406
# The coefficient for cut is 55.65739785769702
# The coefficient for color is -219.42555368160419
# The coefficient for clarity is 263.72188187304766
# The coefficient for depth is -65.39644867081132
# The coefficient for table is -73.34455568914015
# The coefficient for x is 310.6606566457792
# The coefficient for y is 38.68857388776525
# The coefficient for z is -5.749632121779922

# %%
intercept = regression_model.intercept_[0]

print("The intercept for our model is {}".format(intercept))
# Out:
# The intercept for our model is 4278.33777707184

# %%
regression_model.score(X_train, y_train)
# Out:
# 0.8943203899134277

# %%
regression_model.score(X_test, y_test)
# Out:
# 0.8952914956064281

# %%
data_train = pd.concat([X_train, y_train], axis=1)
data_train.head()
# Out:
#        carat  cut  color  clarity  depth  table     x     y     z   price
# 11687   0.41    2      5        7   62.3   56.0  4.77  4.73  2.96  1061.0
# 9728    1.71    2      6        2   62.8   57.0  7.58  7.55  4.75  6320.0
# 1936    0.33    1      2        2   61.8   62.0  4.40  4.45  2.74   536.0
# 26220   0.70    4      4        2   62.8   57.0  5.61  5.66  3.54  2214.0
# 18445   0.70    2      0        3   62.1   56.0  5.67  5.71  3.53  2575.0

# %%
import statsmodels.formula.api as smf
lm1 = smf.ols(formula= 'price ~ carat+depth+table+x+y+z+cut+color+clarity', data = data_train).fit()
lm1.params
# Out:
# Intercept    4278.337777
# carat        6463.821171
# depth         -65.396449
# table         -73.344556
# x             310.660657
# y              38.688574
# z              -5.749632
# cut            55.657398
# color        -219.425554
# clarity       263.721882
# dtype: float64

# %%
print(lm1.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.894
# Model:                            OLS   Adj. R-squared:                  0.894
# Method:                 Least Squares   F-statistic:                 1.774e+04
# Date:                Sun, 14 Feb 2021   Prob (F-statistic):               0.00
# Time:                        17:05:53   Log-Likelihood:            -1.5949e+05
# No. Observations:               18876   AIC:                         3.190e+05
# Df Residuals:                   18866   BIC:                         3.191e+05
# Df Model:                           9
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   4278.3378    573.394      7.461      0.000    3154.435    5402.241
# ...

# %%
mse = np.mean((regression_model.predict(X_test)-y_test)**2)

# %%
import math

math.sqrt(mse)
# Out:
# 1117.4006238254663

# %%
regression_model.score(X_test, y_test)
# Out:
# 0.8952914956064281

# %%
y_pred = regression_model.predict(X_test)

# %%
plt.scatter(y_test['price'], y_pred)

# %%
from scipy.stats import zscore

X_train_scaled  = X_train.apply(zscore)
X_test_scaled = X_test.apply(zscore)
y_train_scaled = y_train.apply(zscore)
y_test_scaled = y_test.apply(zscore)

# %%
regression_model = LinearRegression()
regression_model.fit(X_train_scaled, y_train_scaled)
# Out:
# LinearRegression()

# %%
for idx, col_name in enumerate(X_train.columns):
    print("The coefficient for {} is {}".format(col_name, regression_model.coef_[0][idx]))
# Out:
# The coefficient for carat is 0.8884319714492349
# The coefficient for cut is 0.01644718496549098
# The coefficient for color is -0.1075990040831404
# The coefficient for clarity is 0.13024180079405126
# The coefficient for depth is -0.026229056864908912
# The coefficient for table is -0.04697918002584378
# The coefficient for x is 0.10060941351987777
# The coefficient for y is 0.013161274948294749
# The coefficient for z is -0.0012011336026471584

# %%
intercept = regression_model.intercept_[0]

print("The intercept for our model is {}".format(intercept))
# Out:
# The intercept for our model is 3.126073337679891e-17

# %%
regression_model.score(X_test_scaled, y_test_scaled)
# Out:
# 0.8954056733724498

# %%
mse = np.mean((regression_model.predict(X_test_scaled)-y_test_scaled)**2)

# %%
import math

math.sqrt(mse)
# Out:
# 0.32341046153077746

# %%
y_pred = regression_model.predict(X_test_scaled)

# %%
plt.scatter(y_test_scaled['price'], y_pred)

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
vif = [variance_inflation_factor(X.values, ix) for ix in range(X.shape[1])]

# %%
i=0
for column in X.columns:
    if i < 11:
        print (column ,"--->",  vif[i])
        i = i+1
# Out:
# carat ---> 78.06394234783788
# cut ---> 7.46176386330477
# color ---> 3.67277992644157
# clarity ---> 6.205559887349651
# depth ---> 520.1715366726672
# table ---> 520.8005759674704
# x ---> 1071.5501868535525
# y ---> 348.5435304851296
# z ---> 373.62936004757734
